# %%
# ==============================================
# 🛠️ INSTALL PREPROCESSING DEPENDENCIES (KERNEL-SAFE)
# ==============================================
import sys

# !{sys.executable} -m pip install --upgrade pip
# !{sys.executable} -m pip install \
    opencv-python numpy pillow tqdm matplotlib imageio scikit-image

# %%
import os, sys

# Set project root to the parent of /notebooks
project_root = os.path.abspath(os.path.join(os.getcwd(), ".."))
if project_root not in sys.path:
    sys.path.append(project_root)

# Now safely import and run the environment check
from src.setup.environment_preprocessing import verify_environment
verify_environment(project_root)
# Out:
# 🔧 Verifying preprocessing environment...
# ✅ Folder exists: data
# ✅ Folder exists: models
# ✅ Folder exists: src
# ✅ Folder exists: notebooks
# ✅ Folder exists: tests
# ✅ Folder exists: data/raw_videos
# ✅ Haar cascade files are available.
# ✅ PIL installed and working.
# 🟢 Environment setup verified.

# %%
import os
import sys
import importlib

# Make sure the root is in the path
project_root = os.path.abspath(os.path.join(os.getcwd(), ".."))
if project_root not in sys.path:
    sys.path.append(project_root)

# ✅ Import and reload the extract_frames module
import src.preprocessing.extract_frames as extract_frames
importlib.reload(extract_frames)

# ✅ Now run the function
video_path = os.path.join(project_root, "data", "raw_videos", "vid_001.mpg")
extract_frames.extract_frames_from_video(
    video_path=video_path,
    data_root=os.path.join(project_root, "data")
)
# Out:
# ✅ Extracted 75 frames for video 'vid_001' and saved metadata.
